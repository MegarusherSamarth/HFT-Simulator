# %% [markdown]
# CHARTS, GRAPHS AND ACCURACY REPRESENTATION

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Example
data = {
    "Model": ["LSTM", "RL"], 
    "PnL": [9, 7], 
    "Sharpe": [40.53, 25.12], 
    "WinRate": [1.0, 0.75], 
    "Accuracy": [0.85, 0.78]
}
df = pd.DataFrame(data)

# %%
# Table
print(df)
# Out:
#   Model  PnL  Sharpe  WinRate  Accuracy
# 0  LSTM    9   40.53     1.00      0.85
# 1    RL    7   25.12     0.75      0.78

# %%
# Bar Chart Comparison
from python_strategies.evaluation.backtest_report import BacktestReport

# Example usage
report = BacktestReport(prices=[100,102,105], actions=[0,2,1])
metrics = report.generate_report()
print(metrics)

import pandas as pd 
import matplotlib.pyplot as plt 

df = pd.DataFrame([metrics]) 
df.plot(kind="bar") 
plt.show()
# Out:
# {'PnL': 5.0, 'Sharpe Ratio': np.float64(53.74011537017761), 'Win Rate': 1.0}

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['PnL', 'Sharpe Ratio', 'Win Rate'], dtype='object')
#    PnL  Sharpe Ratio  Win Rate
# 0  5.0     53.740115       1.0

# %%
# Equity curve (synthetic example) 
equity_lstm = [0,2,4,6,9] 
equity_rl = [0,1,3,5,7] 
plt.plot(equity_lstm, label="LSTM") 
plt.plot(equity_rl, label="RL") 
plt.title("Equity Curve") 
plt.legend()
plt.show()
